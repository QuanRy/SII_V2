# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("alcohol-consumption.csv")
df.head(10)
# Out:
#           country  total_consumption  recorded_consumption  \
# 0         Estonia               16.9                  15.8
# 1       Lithuania               15.0                  13.8
# 2  Czech Republic               14.3                  12.4
# 3      Seychelles               13.8                  12.4
# 4         Germany               13.4                  11.3
# 5         Nigeria               13.4                   9.6
# 6         Ireland               13.0                  11.3
# 7         Moldova               13.0                  11.5
# 8          Latvia               12.9                  11.1
# 9        Bulgaria               12.7                  11.4
#
#    unrecorded_consumption  beer_percentage  wine_percentage  \
# 0                     1.1             32.7              7.4
# 1                     1.2             43.6              7.3
# 2                     1.4             53.3             21.3
# 3                     1.4             68.9             22.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 189 non-null    object
#  1   total_consumption       189 non-null    float64
#  2   recorded_consumption    189 non-null    float64
#  3   unrecorded_consumption  189 non-null    float64
#  4   beer_percentage         179 non-null    float64
#  5   wine_percentage         179 non-null    float64
#  6   spirits_percentage      179 non-null    float64
#  7   other_percentage        179 non-null    float64
#  8   2020_projection         189 non-null    float64
#  9   2025_projection         189 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 14.9+ KB

# %%
df.nunique()
# Out:
# country                   189
# total_consumption         103
# recorded_consumption       92
# unrecorded_consumption     37
# beer_percentage           160
# wine_percentage           136
# spirits_percentage        140
# other_percentage           76
# 2020_projection           109
# 2025_projection           108
# dtype: int64

# %%
col_name = ['страна', 'общее_потребление_в_стране', 'зарегистрированное_потребление_в_литрах', 'неучтенное_потребление_в_литрах', 'пиво_в_литрах', 'вина_в_литрах', 'крепкое_спиртное_в_литрах', 'прочий_алкоголь', '2020_предсказание', '2025_предсказание']
df.set_axis(col_name, axis = 'columns')
# Out:
#              страна  общее_потребление_в_стране  \
# 0           Estonia                        16.9
# 1         Lithuania                        15.0
# 2    Czech Republic                        14.3
# 3        Seychelles                        13.8
# 4           Germany                        13.4
# ..              ...                         ...
# 184      Bangladesh                         0.0
# 185          Kuwait                         0.0
# 186           Libya                         0.0
# 187      Mauritania                         0.0
# 188         Somalia                         0.0
#
#      зарегистрированное_потребление_в_литрах  неучтенное_потребление_в_литрах  \
# 0                                       15.8                              1.1
# 1                                       13.8                              1.2
# 2                                       12.4                              1.4
# ...

# %%
df.dropna(subset = ['total_consumption'], inplace = True)
df.total_consumption.unique()
df.total_consumption = df.total_consumption.replace('0.0', np.nan)
df.total_consumption.unique()
# Out:
# array([16.9, 15. , 14.3, 13.8, 13.4, 13. , 12.9, 12.7, 12.6, 12.3, 12.1,
#        11.7, 11.6, 11.5, 11.4, 11.3, 11.2, 11.1, 10.8, 10.7, 10.6, 10.4,
#        10.2, 10. ,  9.9,  9.8,  9.6,  9.5,  9.4,  9.3,  9.2,  9.1,  9. ,
#         8.9,  8.7,  8.6,  8.4,  8.3,  8.2,  8.1,  8. ,  7.9,  7.8,  7.7,
#         7.5,  7.4,  7.2,  7. ,  6.9,  6.8,  6.7,  6.6,  6.5,  6.4,  6.3,
#         6.2,  6.1,  6. ,  5.8,  5.7,  5.6,  5.5,  5.4,  5.2,  5.1,  5. ,
#         4.8,  4.4,  4.3,  4.2,  4. ,  3.9,  3.8,  3.7,  3.6,  3.4,  3.3,
#         3.1,  3. ,  2.8,  2.7,  2.6,  2.5,  2.4,  2.1,  2. ,  1.9,  1.7,
#         1.5,  1.4,  1.3,  1.2,  1. ,  0.9,  0.8,  0.7,  0.6,  0.5,  0.4,
#         0.3,  0.2,  0.1,  0. ])

# %%
df[df['total_consumption'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [country, total_consumption, recorded_consumption, unrecorded_consumption, beer_percentage, wine_percentage, spirits_percentage, other_percentage, 2020_projection, 2025_projection]
# Index: []

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [country, total_consumption, recorded_consumption, unrecorded_consumption, beer_percentage, wine_percentage, spirits_percentage, other_percentage, 2020_projection, 2025_projection]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0
