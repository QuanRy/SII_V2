# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
class Graph():
  def __init__(self):
    self.nodes = nx.Graph()

  def add_node(self, node):
    self.nodes.add_node(node)

  def add_edge(self, node1, node2):
    self.nodes.add_edge(node1, node2)

  def add_neighbors(self, node):
    return list(self.nodes.neighbors(node))

  def get_all_nodes(self):
    return list(self.nodes.nodes)

  #Поиск в глубину
  def dfs(self, start, end):
    visited = set()
    path = []
    self._dfs_util(start, end, visited, path)

    if not path:
      print("Path not found")
    else:
      print("Path:", " -> ".join(str(path)))

  def _dfs_util(self, node, end, visited, path):
    visited.add(node)
    path.append(node)

    if node == end:
      return True

    for neighbor in self.nodes.neighbors(node):
      if neighbor not in visited:
        if self._dfs_util(neighbor, end, visited, path):
          return True
    path.pop()
    return False

  #Поиск в ширину
  def bfs(self, start, end):
    visited = set()
    queue = [(start, [])]

    while queue:
      node, path = queue.pop(0)

      if node not in visited:
        visited.add(node)
        path.append(node)

        if node == end:
          print("Path:", " -> ".join(str(path)))
          return

        for neighbor in self.nodes.neighbors(node):
          if neighbor not in visited:
            queue.append((neighbor, list(path)))

    print("Path not found")

  #Визуализация
  def visualize(self):
    nx.draw(self.nodes, with_labels=True, node_color='lightblue', edge_color='gray', font_weight='bold')
    plt.show()

# %%
#Создание нового графа
graph = Graph()

# Добавление вершин в граф
graph.add_node(1)
graph.add_node(2)
graph.add_node(3)
graph.add_node(4)
graph.add_node(5)
graph.add_node(6)
graph.add_node(7)
graph.add_node(8)
graph.add_node(9)
graph.add_node(10)
graph.add_node(11)
graph.add_node(12)
graph.add_node(13)
graph.add_node(14)
graph.add_node(15)

# Добавление ребер в граф
graph.add_edge(1,3)
graph.add_edge(2,5)
graph.add_edge(2,11)
graph.add_edge(3,2)
graph.add_edge(3,4)
graph.add_edge(4,5)
graph.add_edge(4,6)
graph.add_edge(5,7)
graph.add_edge(6,7)
graph.add_edge(7,8)
graph.add_edge(7,9)
graph.add_edge(8,10)
graph.add_edge(9,10)
graph.add_edge(9,13)
graph.add_edge(10,14)
graph.add_edge(11,12)
graph.add_edge(11,15)
graph.add_edge(12,13)
graph.add_edge(13,14)

# %%
# отрисуем полученный граф (граф из примера)
print("DFS: ")
graph.dfs(1,9)
print("BFS: ")
graph.bfs(1,9)

# Visualize the graph
graph.visualize()
# Out:
# DFS:
# Path: [ -> 1 -> , ->   -> 3 -> , ->   -> 2 -> , ->   -> 5 -> , ->   -> 4 -> , ->   -> 6 -> , ->   -> 7 -> , ->   -> 8 -> , ->   -> 1 -> 0 -> , ->   -> 9 -> ]
# BFS:
# Path: [ -> 1 -> , ->   -> 3 -> , ->   -> 2 -> , ->   -> 5 -> , ->   -> 7 -> , ->   -> 9 -> ]

# %%
#Создание нового графа
graph1 = Graph()

# Добавление вершин в граф
graph1.add_node(1)
graph1.add_node(2)
graph1.add_node(3)
graph1.add_node(4)
graph1.add_node(5)
graph1.add_node(6)
graph1.add_node(7)
graph1.add_node(8)
graph1.add_node(9)
graph1.add_node(10)
graph1.add_node(11)
graph1.add_node(12)
graph1.add_node(13)
graph1.add_node(14)
graph1.add_node(15)

# Добавление ребер в граф
graph1.add_edge(1,3)
graph1.add_edge(2,5)
graph1.add_edge(3, 4)
graph1.add_edge(5, 6)
graph1.add_edge(7, 8)
graph1.add_edge(9, 10)
graph1.add_edge(11, 12)
graph1.add_edge(13, 14)
graph1.add_edge(15, 1)
graph1.add_edge(2, 4)
graph1.add_edge(6, 8)
graph1.add_edge(10, 12)
graph1.add_edge(14, 1)
graph1.add_edge(3, 10)
graph1.add_edge(7, 9)
graph1.add_edge(11, 13)
graph1.add_edge(15, 2)
graph1.add_edge(4, 6)
graph1.add_edge(7, 3)
graph1.add_edge(12, 14)
graph1.add_edge(3, 14)
graph1.add_edge(3, 15)
graph1.add_edge(4, 7)
graph1.add_edge(7, 10)

# %%
print("DFS: ")
graph1.dfs(1,14)
print("BFS: ")
graph1.bfs(1,11)

# Visualize the graph
graph1.visualize()
# Out:
# DFS:
# Path: [ -> 1 -> , ->   -> 3 -> , ->   -> 4 -> , ->   -> 2 -> , ->   -> 5 -> , ->   -> 6 -> , ->   -> 8 -> , ->   -> 7 -> , ->   -> 9 -> , ->   -> 1 -> 0 -> , ->   -> 1 -> 2 -> , ->   -> 1 -> 1 -> , ->   -> 1 -> 3 -> , ->   -> 1 -> 4 -> ]
# BFS:
# Path: [ -> 1 -> , ->   -> 1 -> 4 -> , ->   -> 1 -> 3 -> , ->   -> 1 -> 1 -> ]

# %%
#Создание нового графа
graph1 = Graph()

# Добавление вершин в граф
graph1.add_node(1)
graph1.add_node(2)
graph1.add_node(3)
graph1.add_node(4)
graph1.add_node(5)
graph1.add_node(6)
graph1.add_node(7)
graph1.add_node(8)
graph1.add_node(9)
graph1.add_node(10)
graph1.add_node(11)
graph1.add_node(12)
graph1.add_node(13)
graph1.add_node(14)
graph1.add_node(15)

# Добавление ребер в граф
graph1.add_edge(1, 4)
graph1.add_edge(2, 6)
graph1.add_edge(3, 8)
graph1.add_edge(5, 10)
graph1.add_edge(9, 14)
graph1.add_edge(11, 3)
graph1.add_edge(13, 7)
graph1.add_edge(15, 11)
graph1.add_edge(4, 9)
graph1.add_edge(6, 13)
graph1.add_edge(8, 15)
graph1.add_edge(10, 2)
graph1.add_edge(12, 12)
graph1.add_edge(1, 14)
graph1.add_edge(1, 15)

# %%
print("DFS: ")
graph1.dfs(1,14)
print("BFS: ")
graph1.bfs(2,12)

# Visualize the graph
graph1.visualize()
# Out:
# DFS:
# Path: [ -> 1 -> , ->   -> 4 -> , ->   -> 9 -> , ->   -> 1 -> 4 -> ]
# BFS:
# Path not found

# %%
#Создание нового графа
graph1 = Graph()

# Добавление вершин в граф
graph1.add_node(1)
graph1.add_node(2)
graph1.add_node(3)
graph1.add_node(4)
graph1.add_node(5)
graph1.add_node(6)
graph1.add_node(7)
graph1.add_node(8)
graph1.add_node(9)
graph1.add_node(10)
graph1.add_node(11)
graph1.add_node(12)
graph1.add_node(13)
graph1.add_node(14)
graph1.add_node(15)

# Добавление ребер в граф
graph1.add_edge(3, 1)
graph1.add_edge(3, 4)
graph1.add_edge(2, 1)
graph1.add_edge(4, 6)
graph1.add_edge(5, 2)
graph1.add_edge(5, 7)
graph1.add_edge(6, 9)
graph1.add_edge(6, 8)
graph1.add_edge(7, 10)
graph1.add_edge(8, 11)
graph1.add_edge(9, 12)
graph1.add_edge(10, 13)
graph1.add_edge(11, 14)
graph1.add_edge(12, 15)
graph1.add_edge(13, 14)
graph1.add_edge(14, 15)
graph1.add_edge(15,11)
graph1.add_edge(11,12)
graph1.add_edge(12,9)
graph1.add_edge(9,8)
graph1.add_edge(12,8)
graph1.add_edge(11,2)

# %%
print("DFS: ")
graph1.dfs(1,14)
print("BFS: ")
graph1.bfs(1,11)

# Visualize the graph
graph1.visualize()
# Out:
# DFS:
# Path: [ -> 1 -> , ->   -> 3 -> , ->   -> 4 -> , ->   -> 6 -> , ->   -> 9 -> , ->   -> 1 -> 2 -> , ->   -> 1 -> 5 -> , ->   -> 1 -> 4 -> ]
# BFS:
# Path: [ -> 1 -> , ->   -> 2 -> , ->   -> 1 -> 1 -> ]
